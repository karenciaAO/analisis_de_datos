# %%
# SQLAlchemy == 2.0.29
# mysql-connector-python==8.3.0
# mysqlclient==2.2.4
# !pip install SQLAlchemy==2.0.29
# !pip install mysql-connector-python==8.3.0
# !pip install mysqlclient==2.2.4

# %% [markdown]
# ## Para usar el mysql con docker
# ```bash
# docker compose up
# docker exec -it analisis_datos_datapath-mysql-1 bash
# ```

# %%
import pandas as pd
import sqlalchemy as db
from sqlalchemy import text

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn=engine.connect()

# %%
df = pd.read_sql_query(text('select * from customers'),con=conn)

# %%
df.head()
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0            1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1            2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2            3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3            4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4            5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
#
#            customer_street customer_city customer_state customer_zipcode
# 0       6303 Heather Plaza   Brownsville             TX            78521
# 1  9526 Noble Embers Ridge     Littleton             CO            80126
# 2   3422 Blue Pioneer Bend        Caguas             PR            00725
# 3       8324 Little Common    San Marcos             CA            92069
# 4   10 Crystal River Mall         Caguas             PR            00725

# %%
# !pip install pymongo

# %%
import pandas as pd
from pymongo import MongoClient
import sqlalchemy as db

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn=engine.connect()

# %%
customers_df=pd.read_sql('customers',con=conn)

# %%
connection_string='mongodb+srv://karenaraqueo:2NXVETfHmiLG0v8k@cluster0.dzr0y.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

client=MongoClient(connection_string)

# %%
#pasword se remplasa en el enlace que 
#sacamos de mongo conection en drivers 
#en en el enlace la agregamos1aMHd26JAIYIjebP

# %%
#leemos crea la coleccion

# %%
db_name= client['retail_db']
collection_name=db_name['customers']

# %%
df_to_dict=customers_df.to_dict("records")
collection_name.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('66ecd2e212ee77f06adb553b'), ObjectId('66ecd2e212ee77f06adb553c'), ObjectId('66ecd2e212ee77f06adb553d'), ObjectId('66ecd2e212ee77f06adb553e'), ObjectId('66ecd2e212ee77f06adb553f'), ObjectId('66ecd2e212ee77f06adb5540'), ObjectId('66ecd2e212ee77f06adb5541'), ObjectId('66ecd2e212ee77f06adb5542'), ObjectId('66ecd2e212ee77f06adb5543'), ObjectId('66ecd2e212ee77f06adb5544'), ObjectId('66ecd2e212ee77f06adb5545'), ObjectId('66ecd2e212ee77f06adb5546'), ObjectId('66ecd2e212ee77f06adb5547'), ObjectId('66ecd2e212ee77f06adb5548'), ObjectId('66ecd2e212ee77f06adb5549'), ObjectId('66ecd2e212ee77f06adb554a'), ObjectId('66ecd2e212ee77f06adb554b'), ObjectId('66ecd2e212ee77f06adb554c'), ObjectId('66ecd2e212ee77f06adb554d'), ObjectId('66ecd2e212ee77f06adb554e'), ObjectId('66ecd2e212ee77f06adb554f'), ObjectId('66ecd2e212ee77f06adb5550'), ObjectId('66ecd2e212ee77f06adb5551'), ObjectId('66ecd2e212ee77f06adb5552'), ObjectId('66ecd2e212ee77f06adb5553'), ObjectId('66ecd2e212ee77f06adb
# ...

# %%
customers=collection_name.find({'customer_state':'NJ'})

# %%
#asi como convetimos A COLLECTIO PARA LLEVAR A MONGO 

customers_df=pd.DataFrame(customers)

# %%
customers_df
# Out:
#                           _id  customer_id customer_fname customer_lname  \
# 0    66ecd2e212ee77f06adb5540            6           Mary          Smith
# 1    66ecd2e212ee77f06adb554e           20           Mary          Ellis
# 2    66ecd2e212ee77f06adb5550           22         Joseph          Smith
# 3    66ecd2e212ee77f06adb557b           65       Jennifer          Smith
# 4    66ecd2e212ee77f06adb55d0          150           Mary          Smith
# ..                        ...          ...            ...            ...
# 214  66ecd2e212ee77f06adb83fe        11972          Henry          Smith
# 215  66ecd2e212ee77f06adb840b        11985       Jennifer           Moss
# 216  66ecd2e212ee77f06adb8436        12028         Steven          Smith
# 217  66ecd2e212ee77f06adb845c        12066          Kevin          Smith
# 218  66ecd2e212ee77f06adb857f        12357          Harry          Smith
#
#     customer_email customer_password              customer_street  \
# ...
